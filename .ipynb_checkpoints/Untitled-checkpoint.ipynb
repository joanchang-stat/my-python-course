# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv('C:/Users/joan/Desktop/step-optimization/Equip.csv',encoding = 'unicode_escape')

# %%
df.head(10)
# Out:
#     Schdule     HId     TId          LId  \
# 0  912QMLN1  HM4101  THM571  QQ-L/B-1185
# 1  916QMB51  HMF011  THMG21  QQ-L/B-1191
# 2  924QMG81  HMF011  THMG21  QQ-L/B-1191
# 3  925QMB91  HYL061  THM781  QQ-L/B-1214
# 4  925QMBC1  HYL061  THM781  QQ-L/B-1214
# 5  927QME41  HYL061  THM781  QQ-L/B-1214
# 6  928QMLC1  HM4061  THMA71  QQ-L/B-1207
# 7  929QMJR1  HM4101  THM571  QQ-L/B-1221
# 8  930QMFL1  HM4031  THM271  QQ-L/B-1225
# 9  931QMA21  HM4101  THM571  QQ-L/B-1221
#
#         SKIds(¥H||¤À¹j¡A´`§Ç¹ïÀ³testResultªºsiteNum)
# 0  5RIC8-292||5RIC8-255||5RIC8-002||5RIC8-374||5R...
# 1  5RIC8-228||5RIC8-233||5RIC8-290||5RIC8-108||5R...
# 2  5RIC8-228||5RIC8-041||5RIC8-395||5RIC8-108||5R...
# 3  5RIC8-308||5RIC8-003||5RIC8-390||5RIC8-018||5R...
# 4  5RIC8-308||5RIC8-003||5RIC8-390||5RIC8-018||5R...
# 5  5RIC8-056||5RIC8-003||5RIC8-392||5RIC8-018||5R...
# 6  5RIC8-367||5RIC8-005||5RIC8-124||5RIC8-008||5R...
# 7  5RIC8-267||5RIC8-081||5RIC8-086||5RIC8-188||5R...
# ...

# %%
df.head(10)
# Out:
#     Schdule     HId     TId          LId  \
# 0  912QMLN1  HM4101  THM571  QQ-L/B-1185
# 1  916QMB51  HMF011  THMG21  QQ-L/B-1191
# 2  924QMG81  HMF011  THMG21  QQ-L/B-1191
# 3  925QMB91  HYL061  THM781  QQ-L/B-1214
# 4  925QMBC1  HYL061  THM781  QQ-L/B-1214
# 5  927QME41  HYL061  THM781  QQ-L/B-1214
# 6  928QMLC1  HM4061  THMA71  QQ-L/B-1207
# 7  929QMJR1  HM4101  THM571  QQ-L/B-1221
# 8  930QMFL1  HM4031  THM271  QQ-L/B-1225
# 9  931QMA21  HM4101  THM571  QQ-L/B-1221
#
#         SKIds(¥H||¤À¹j¡A´`§Ç¹ïÀ³testResultªºsiteNum)
# 0  5RIC8-292||5RIC8-255||5RIC8-002||5RIC8-374||5R...
# 1  5RIC8-228||5RIC8-233||5RIC8-290||5RIC8-108||5R...
# 2  5RIC8-228||5RIC8-041||5RIC8-395||5RIC8-108||5R...
# 3  5RIC8-308||5RIC8-003||5RIC8-390||5RIC8-018||5R...
# 4  5RIC8-308||5RIC8-003||5RIC8-390||5RIC8-018||5R...
# 5  5RIC8-056||5RIC8-003||5RIC8-392||5RIC8-018||5R...
# 6  5RIC8-367||5RIC8-005||5RIC8-124||5RIC8-008||5R...
# 7  5RIC8-267||5RIC8-081||5RIC8-086||5RIC8-188||5R...
# ...
